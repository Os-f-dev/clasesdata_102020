# %%
import dask

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv('flights.csv', assume_missing=True)

# %%
df.head()
# Out:
#      YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015.0    1.0  1.0          4.0      AS           98.0      N407AS
# 1  2015.0    1.0  1.0          4.0      AA         2336.0      N3KUAA
# 2  2015.0    1.0  1.0          4.0      US          840.0      N171US
# 3  2015.0    1.0  1.0          4.0      AA          258.0      N3HYAA
# 4  2015.0    1.0  1.0          4.0      AS          135.0      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                  5.0  ...         408.0
# 1            LAX                 PBI                 10.0  ...         741.0
# 2            SFO                 CLT                 20.0  ...         811.0
# 3            LAX                 MIA                 20.0  ...         756.0
# 4            SEA                 ANC                 25.0  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
type(df)
# Out:
# dask.dataframe.core.DataFrame

# %%
df
# Out:
# Dask DataFrame Structure:
#                    YEAR    MONTH      DAY DAY_OF_WEEK AIRLINE FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME DEPARTURE_DELAY TAXI_OUT WHEELS_OFF SCHEDULED_TIME ELAPSED_TIME AIR_TIME DISTANCE WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME ARRIVAL_DELAY DIVERTED CANCELLED CANCELLATION_REASON AIR_SYSTEM_DELAY SECURITY_DELAY AIRLINE_DELAY LATE_AIRCRAFT_DELAY WEATHER_DELAY
# npartitions=18
#                 float64  float64  float64     float64  object       float64      object         object              object             float64        float64         float64  float64    float64        float64      float64  float64  float64   float64  float64           float64      float64       float64  float64   float64              object          float64        float64       float64             float64       float64
# ...

# %%
df.tail()
# Out:
#           YEAR  MONTH   DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 213554  2015.0   12.0  31.0          4.0      B6          688.0      N657JB
# 213555  2015.0   12.0  31.0          4.0      B6          745.0      N828JB
# 213556  2015.0   12.0  31.0          4.0      B6         1503.0      N913JB
# 213557  2015.0   12.0  31.0          4.0      B6          333.0      N527JB
# 213558  2015.0   12.0  31.0          4.0      B6          839.0      N534JB
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 213554            LAX                 BOS               2359.0  ...
# 213555            JFK                 PSE               2359.0  ...
# 213556            JFK                 SJU               2359.0  ...
# 213557            MCO                 SJU               2359.0  ...
# 213558            JFK                 BQN               2359.0  ...
#
#         ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# ...

# %%
df.info(memory_usage = 'deep')
# Out:
# c:\program files\lib\site-packages\dask\core.py:121: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 31 entries, YEAR to WEATHER_DELAY
# dtypes: object(5), float64(26)
# memory usage: 1.3 GB

# %%
df.isna().sum().compute()
# Out:
# c:\program files\lib\site-packages\dask\core.py:121: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14721
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           86153
# DEPARTURE_DELAY          86153
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# SCHEDULED_TIME               6
# ELAPSED_TIME            105071
# AIR_TIME                105071
# DISTANCE                     0
# WHEELS_ON                92513
# TAXI_IN                  92513
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             92513
# ARRIVAL_DELAY           105071
# ...

# %%
import pandas as pd

# %%
df.DEPARTURE_DELAY.max().compute()
df.DEPARTURE_DELAY.max().visualize()
# Out:
# c:\program files\lib\site-packages\dask\core.py:121: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# Format: "png" not recognized. Use one of:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-24-f204ee0f565a> in <module>
#       1 df.DEPARTURE_DELAY.max().compute()
# ----> 2 df.DEPARTURE_DELAY.max().visualize()
#
# c:\program files\lib\site-packages\dask\base.py in visualize(self, filename, format, optimize_graph, **kwargs)
#      96             format=format,
#      97             optimize_graph=optimize_graph,
# ---> 98             **kwargs
#      99         )
#     100
#
# c:\program files\lib\site-packages\dask\base.py in visualize(*args, **kwargs)
#     556         raise NotImplementedError("Unknown value color=%s" % color)
#     557
# ...

# %%
# !pip install graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\program files\python.exe -m pip install --upgrade pip' command.

# %%
df.groupby('ORIGIN_AIRPORT').DEPARTURE_DELAY.mean().compute()
# Out:
# c:\program files\lib\multiprocessing\pool.py:121: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# ORIGIN_AIRPORT
# ABE       8.844812
# ABI       5.783989
# ABQ       8.877015
# ABR      10.101056
# ABY       8.880046
#            ...
# 16218     0.615385
# 13502    -5.800000
# 13502    -5.000000
# 14025     8.000000
# 14222    -5.000000
# Name: DEPARTURE_DELAY, Length: 934, dtype: float64

# %%
df_2 = pd.read_csv('flights.csv')
# Out:
# C:\Users\GralG\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_2.groupby('ORIGIN_AIRPORT').DEPARTURE_DELAY.mean()
# Out:
# ORIGIN_AIRPORT
# 10135    10.075221
# 10136     3.368132
# 10140     5.682484
# 10141     1.803030
# 10146     9.500000
#            ...
# WRG       3.091884
# WYS       1.375000
# XNA      11.886184
# YAK      -6.292237
# YUM       1.232470
# Name: DEPARTURE_DELAY, Length: 930, dtype: float64

# %%
import time
from tqdm import tqdm

# %%
for i in tqdm(range(3), desc = 'Primer_loop'):
    tqdm._instances.clear()
    for j in tqdm(range(5), desc = 'segundo loop'):
        time.sleep(0.5)
# Out:
# ...
# Primer_loop: 100%|███████████████████████████████████████████████████████████████████████| 3/3 [00:07<00:00,  2.56s/it]

# %%
import numpy as np

# %%
df=pd.DataFrame(np.random.randint(0, int(1e8), (10000, 1000)))

# %%
df
# Out:
#            0         1         2         3         4         5         6    \
# 0     23950588  62536108  32074599  85591247  98867627  78308000  15625858
# 1     60472458  33208336  17227750  48110617  71790102  14960037  25119606
# 2     46741228  75633035  83998548  87223264  52787065  53463101  34392455
# 3      6994380  30731122  73625599   7161795  51665509  84976757  35936500
# 4     46033540  12925004  48325889  87221439  78078110  25603019  26340048
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  51833942  50185546  16873932  72959632  65693562   7621336  26583776
# 9996  69627377  71851015  93777383  74957592   2568732  34596752  88897637
# 9997  69831178  91300370   5863054  28180205  62575493  24765508  57050616
# 9998  24423594  12583392   2166712  90302597  31642900  24726788  89036850
# 9999  48207799   9246891  90094815  84795054  84137908  62148236  52394297
#
# ...

# %%
tqdm.pandas()

df.groupby(0).progress_apply(lambda x: x**2)
# Out:
#   3%|██▋                                                                           | 346/10000 [01:10<32:57,  4.88it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-7887234dc440> in <module>
#       1 tqdm.pandas()
#       2
# ----> 3 df.groupby(0).progress_apply(lambda x: x**2)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tqdm\std.py in inner(df, func, *args, **kwargs)
#     768                 # on the df using our wrapper (which provides bar updating)
#     769                 try:
# --> 770                     return getattr(df, df_function)(wrapper, **kwargs)
#     771                 finally:
#     772                     t.close()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     723         with option_context("mode.chained_assignment", None):
# ...

# %%
df.groupby(0).apply(lambda x: x**2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-236ea414b0cb> in <module>
# ----> 1 df.groupby(0).apply(lambda x: x**2)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     723         with option_context("mode.chained_assignment", None):
#     724             try:
# --> 725                 result = self._python_apply_general(f)
#     726             except Exception:
#     727
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     740
#     741     def _python_apply_general(self, f):
# --> 742         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     743
#     744         return self._wrap_applied_output(
#
# ...
